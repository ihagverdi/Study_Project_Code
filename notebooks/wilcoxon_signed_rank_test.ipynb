# %%
from tabpfn_project.globals import DISTNET_SCENARIOS
from tabpfn_project.helper.utils import analyze_optimal_context
from tabpfn_project.paths import RESULTS_DIR


results_df = analyze_optimal_context(
    model_results_path=RESULTS_DIR / "GaussianProcess" / "gp_results_exp_random_subsample_log.pkl",
    scenarios=DISTNET_SCENARIOS,
    metric='NLLH',
    output_csv_path=RESULTS_DIR / "GaussianProcess" / "gp_log_optimal_context_by_scenario_NLLH.csv"
)
# Out:
# ...
#  Parsimony Analysis | Scenario: clasp_factoring | Metric: NLLH
# ...
# Empirical Best Context Size (C_best) : 1024
# Optimal Context Size Chosen          : 1024
# ---------------------------------------------------------------------------
#  Context Size Mean NLLH Std NLLH p-value (vs Best)                            Status
#            32   0.05889  0.05962            0.0010               Significantly Worse
#            64  -0.00055  0.03271            0.0010               Significantly Worse
#           128  -0.02565  0.02576            0.0010               Significantly Worse
#           256  -0.04082  0.02188            0.0010               Significantly Worse
#           512  -0.04661  0.01869            0.0010               Significantly Worse
#          1024  -0.05169  0.01911            1.0000 *** Empirical Best *** <-- CHOSEN
#          2048  -0.04846  0.01896            0.0029               Significantly Worse
# ...
